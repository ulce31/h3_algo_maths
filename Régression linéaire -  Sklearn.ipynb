# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
price_ava = pd.read_csv('./datasets/price_availability.csv', sep=';'); price_ava
# Out:
#          listing_id         day                       created  available  \
# 0           9810829  2018-12-08  2018-09-27 06:14:10.000+0000       True
# 1           9810829  2018-12-08  2018-09-26 19:34:02.000+0000       True
# 2          20897010  2018-12-09  2018-09-27 10:38:57.000+0000       True
# 3          20897010  2018-12-09  2018-09-27 06:10:27.000+0000       True
# 4          20897010  2018-12-09  2018-09-26 19:30:25.000+0000       True
# ...             ...         ...                           ...        ...
# 4748691    23608395  2018-09-06  2018-09-27 06:05:42.000+0000      False
# 4748692    23608395  2018-09-06  2018-09-26 19:31:32.000+0000      False
# 4748693     1447132  2018-12-27  2018-09-27 10:46:16.000+0000      False
# 4748694     1447132  2018-12-27  2018-09-27 06:07:36.000+0000      False
# 4748695     1447132  2018-12-27  2018-09-26 19:37:40.000+0000      False
#
#         local_currency  local_price  min_nights
# ...

# %%
#listings_final.csv
listing_final = pd.read_csv('./datasets/listings_final.csv', sep=';').iloc[:, 1:]; listing_final
# Out:
#      listing_id                                      name          type  \
# 0      28581061                           La maison Clery  private_room
# 1        661961       studio PARIS PLACE EDITH PIAF 75020   entire_home
# 2       1261705  chambre privée à louer @ paris oberkampf  private_room
# 3       1318834            Appartement au coeur du Marais   entire_home
# 4       1677091                       Lovely & Quiet flat   entire_home
# ..          ...                                       ...           ...
# 995    28335197          Studio cosy Jardin du Luxembourg   entire_home
# 996    28583013    Charmant  30m2 - Faubourg Saint Martin   entire_home
# 997    28628316       Cosy flat in the marais - Best area   entire_home
# 998    28792796         Appartement 3 chambres madeleine.   entire_home
# 999    28682896                          Village Jourdain  private_room
#
#       city                    neighborhood   latitude  longitude  \
# ...

# %%
for index, row in listing_final.iterrows():
    if row["listing_id"] in price_ava["listing_id"]:
        #print(row["listing_id"] ,price_ava_GB_LID.get_group(row["listing_id"]))
        cleaned_df[""]
        print(price_ava_GB_LID.get_group(row["listing_id"]).local_price.mean())
# Out:
# 44.473684210526315
# 49.0
# 165.0
# 69.77443609022556
# 80.56363636363636
# 61.10909090909091
# 169.0
# 170.0
# 49.95275590551181
# 35.06887755102041
# 107.37402597402597
# 76.06896551724138
# 36.58961038961039
# 75.8762088974855
# 284.35356200527707
# 300.0
# 59.07772020725388
# 101.37984496124031
# 67.20833333333333
# 60.740932642487046
# 38.0
# 92.0
# 66.21204188481676
# 79.68041237113403
# 90.09819121447029
# 170.0
# 115.75447570332481
# 283.76115485564304
# 144.74424552429667
# 347.67015706806285
# 115.0
# 105.0
# 154.65384615384616
# 380.0
# 44.16569200779727
# 233.6917098445596
# 147.96623376623376
# 105.0
# 163.47286821705427
# 190.0
# 180.95287958115182
# 128.86304909560724
# 163.28571428571428
# 94.0
# 94.97619047619048
# 218.96373056994818
# 234.89460154241644
# 300.7864077669903
# 62.0
# 59.023498694516974
# 80.24479166666667
# 53.0
# 92.0
# 210.87855297157623
# 278.90625
# 165.0
# 179.67315175097275
# 105.71849865951742
# 43.84615384615385
# 105.15873015873017
# 165.0
# ...

# %%
# on créé g --> tableau de clés associatives de la forme [listing_id => [ses historiques de prix]]
g = price_ava.groupby('listing_id');

# on ajoute une nouvelle colonne dans le DataFrame qui contient toutes les infos

listing_final['price_avg'] = 0


# on fait un boucle sur les lignes du DataFrame qui contient toutes les infos (i = index, x = data)

for (i,x) in listing_final.iterrows():
    #on vérifie que le listing_id possède bien des historiques de prix en regardant si la valeur de listing_id est bien une clé du tableau d'historique g

    if x.listing_id in g.groups.keys():

    # on ajoute pour la ligne i (qui correspond à la ligne) et pour la colonne price_avg la moyenne de tous les historiques de prix

        listing_final.loc[i,'price_avg'] = g.get_group(x.listing_id).local_price.mean()

listing_final
# Out:
#      listing_id                                      name          type  \
# 0      28581061                           La maison Clery  private_room
# 1        661961       studio PARIS PLACE EDITH PIAF 75020   entire_home
# 2       1261705  chambre privée à louer @ paris oberkampf  private_room
# 3       1318834            Appartement au coeur du Marais   entire_home
# 4       1677091                       Lovely & Quiet flat   entire_home
# ..          ...                                       ...           ...
# 995    28335197          Studio cosy Jardin du Luxembourg   entire_home
# 996    28583013    Charmant  30m2 - Faubourg Saint Martin   entire_home
# 997    28628316       Cosy flat in the marais - Best area   entire_home
# 998    28792796         Appartement 3 chambres madeleine.   entire_home
# 999    28682896                          Village Jourdain  private_room
#
#       city                    neighborhood   latitude  longitude  \
# ...

# %%
X, y = listing_final.loc[:, ['person_capacity','beds', 'bedrooms', 'bathrooms']], listing_final["price_avg"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# a => ax + b
reg.coef_
# Out:
# array([ 29.59671631, -21.65999863,  26.87560788, 119.08053273])

# %%
# b => ax + b
reg.intercept_
# Out:
# -57.96611143144261

# %%
reg.score(X_train, y_train)
# Out:
# 0.386812548530045

# %%
regr = LinearRegression()
regr.fit(X_train.values, y_train)
# Out:
# LinearRegression()

# %%
Y_pred = regr.predict(X_test)
len(Y_pred)
# Out:
# 300

# %%
print("Mean squared error : %.2f"
      % mean_squared_error(y_test, Y_pred))
print ('Variance score: %.2f' % r2_score())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-140ecfdbdfdf> in <module>
#       1 print("Mean squared error : %.2f"
# ----> 2       % mean_squared_error(y_test, Y_pred))
#       3 print ('Variance score: %.2f' % r2_score())
#
# NameError: name 'mean_squared_error' is not defined
