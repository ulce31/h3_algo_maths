# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Import des dataset

# %%
fraud = pd.read_csv('./datasets/Fraud_Data.csv'); fraud
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 0         22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1        333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2          1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3        150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4        221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
# ...         ...                  ...                  ...             ...
# 151107   345170  2015-01-27 03:03:34  2015-03-29 00:30:47              43
# 151108   274471  2015-05-15 17:43:29  2015-05-26 12:24:39              35
# 151109   368416  2015-03-03 23:07:31  2015-05-20 07:07:47              40
# 151110   207709  2015-07-09 20:06:07  2015-09-07 09:34:46              46
# 151111   138208  2015-06-10 07:02:20  2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class
# ...

# %%
ip_address  = pd.read_csv('./datasets/IpAddress_to_Country.csv'); ip_address
# Out:
#         lower_bound_ip_address  upper_bound_ip_address    country
# 0                 1.677722e+07                16777471  Australia
# 1                 1.677747e+07                16777727      China
# 2                 1.677773e+07                16778239      China
# 3                 1.677824e+07                16779263  Australia
# 4                 1.677926e+07                16781311      China
# ...                        ...                     ...        ...
# 138841            3.758092e+09              3758093311  Hong Kong
# 138842            3.758093e+09              3758094335      India
# 138843            3.758095e+09              3758095871      China
# 138844            3.758096e+09              3758096127  Singapore
# 138845            3.758096e+09              3758096383  Australia
#
# [138846 rows x 3 columns]

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  object
#  2   purchase_time   151112 non-null  object
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  object
#  5   source          151112 non-null  object
#  6   browser         151112 non-null  object
#  7   sex             151112 non-null  object
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  float64
#  10  class           151112 non-null  int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 12.7+ MB

# %%
ip_address.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138846 entries, 0 to 138845
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   lower_bound_ip_address  138846 non-null  float64
#  1   upper_bound_ip_address  138846 non-null  int64
#  2   country                 138846 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.2+ MB

# %%
fraud["ip_address"]
# Out:
# 0         7.327584e+08
# 1         3.503114e+08
# 2         2.621474e+09
# 3         3.840542e+09
# 4         4.155831e+08
#               ...
# 151107    3.451155e+09
# 151108    2.439047e+09
# 151109    2.748471e+09
# 151110    3.601175e+09
# 151111    4.103825e+09
# Name: ip_address, Length: 151112, dtype: float64

# %%
ip_address["upper_bound_ip_address"]
# Out:
# 0           16777471
# 1           16777727
# 2           16778239
# 3           16779263
# 4           16781311
#              ...
# 138841    3758093311
# 138842    3758094335
# 138843    3758095871
# 138844    3758096127
# 138845    3758096383
# Name: upper_bound_ip_address, Length: 138846, dtype: int64

# %%
countries  = []

# %%
for i in range (len(fraud)):
    ip_address_col = fraud.loc[i, 'ip_address']
    tmp = ip_address[ (ip_address["lower_bound_ip_address"]  <= ip_address_col)  & (ip_address["upper_bound_ip_address"] >= ip_address_col)  ]
    if len(tmp) == 1:
        countries.append(tmp["country"].values[0])
    else :
        countries.append('NA')
fraud['country'] = countries
fraud.head()
# Out:
#    user_id          signup_time        purchase_time  purchase_value  \
# 0    22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1   333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2     1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3   150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4   221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class        country
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0          Japan
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0  United States
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1  United States
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0             NA
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0  United States

# %% [markdown]
# ## Time diff implement

# %% [markdown]
# #### L'objectif:
# Dans le DataFrame 'fraud':
# - Avoir une nouvelle colone 'time_diff' (purchase_time - signup_time)
#
# L'idée:
#
# Cas évidents :
# - présence de NA dans les dates :
#     - si les deux n'ont pas de valeur => "NA"
#     - si c'est 'purchase' => 'purchase' <- '
